# %% [markdown]
# # Gemma 4 Structural Engineering Assistant - Google Colab Training
#
# Notebook ini dirancang untuk melakukan ekstraksi SNI dan fine-tuning model Gemma 4 untuk Teknik Sipil.

# %% [markdown]
# ### 1. Sinkronisasi dengan Project

# %%
# !git clone https://github.com/tech4iddev/COLAB_GEMMA_4.git
# %cd COLAB_GEMMA_4

# %% [markdown]
# ### 2. Install Library (Unsloth & Marker)

# %%
# !pip install -r requirements_colab.txt

# %% [markdown]
# ### 3. Ekstraksi PDF SNI ke Markdown (Opsional)

# %%
# !python extract_colab.py

# %% [markdown]
# ### 4. Jalankan Fine-Tuning (Gemma 4)

# %%
# !python train_colab.py
